# %%
# Cell 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Set visualization style
sns.set(style="whitegrid")
# %matplotlib inline

# %%
# Cell 2: Load the dataset
# REPLACE 'your_file.csv' with your actual file path
file_path = 'Ads2024_IssuesbyCreative_090124-110624_HSE_AI_013026.csv'

try:
    df = pd.read_csv(file_path)
    print("Data loaded successfully!")
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found.")
# Out:
# Data loaded successfully!

# %%
# Cell 3: View the first 5 rows to understand the format
df.head()
# Out:
#   advertiser_party advertiser_type            advertiser     airdate  \
# 0         Democrat       Candidate    Titus for NV CD-01  2024-09-13
# 1         Democrat       Candidate    Hoyle for OR CD-04  2024-09-03
# 2         Democrat       Candidate  Vasquez for NM CD-02  2024-09-11
# 3       Republican     Issue Group                  NRCC  2024-09-13
# 4      Independent     Issue Group             Fairshake  2024-09-05
#
#   election_state               election         issue_1        issue_2  \
# 0             NV  NV CD-01 2024 General        Abortion          Crime
# 1             OR  OR CD-04 2024 General       Education           Jobs
# 2             NM  NM CD-02 2024 General  Bipartisanship    Immigration
# 3             AK  AK CD-AL 2024 General       Joe Biden  Kamala Harris
# 4             AK  AK CD-AL 2024 General        Abortion    Environment
#
#      issue_3                    market  ...  issue_spanlang  primary  special  \
# ...

# %%
# Cell 5: Get a summary of data types and non-null values
# This helps identify if numbers are stored as strings (objects)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 942763 entries, 0 to 942762
# Data columns (total 66 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   advertiser_party     942763 non-null  str
#  1   advertiser_type      942763 non-null  str
#  2   advertiser           942763 non-null  str
#  3   airdate              942763 non-null  str
#  4   election_state       942763 non-null  str
#  5   election             942763 non-null  str
#  6   issue_1              942750 non-null  str
#  7   issue_2              774593 non-null  str
#  8   issue_3              498617 non-null  str
#  9   market               942763 non-null  str
#  10  spent                942763 non-null  float64
#  11  grps                 934911 non-null  float64
#  12  viewers              934911 non-null  float64
#  13  grps_55              934911 non-null  float64
#  14  viewers_55           934911 non-null  float64
# ...

# %%
len(df)
# Out:
# 942763

# %%
df["tone"]
# Out:
# 0         Contrast
# 1         Positive
# 2         Positive
# 3         Negative
# 4         Positive
#             ...
# 942758    Positive
# 942759    Positive
# 942760    Contrast
# 942761    Contrast
# 942762    Positive
# Name: tone, Length: 942763, dtype: str

# %%
df['program_name']
# Out:
# 0             8 News Now at 6:30 PM
# 1               The Big Bang Theory
# 2          Live With Kelly and Mark
# 3                         News at 4
# 4                          The View
#                     ...
# 942758     Men's College Basketball
# 942759    Spectrum News 1 Charlotte
# 942760          News 12 Long Island
# 942761          News 12 Long Island
# 942762                          NaN
# Name: program_name, Length: 942763, dtype: str

# %%
df['transcript']
# Out:
# 0         Wanna sit in the exam room and make decisions ...
# 1         As a single mom, I struggled to pay my bills. ...
# 2         In New Mexico. We know hard work is how things...
# 3         I've been on six deployments. So we're in on S...
# 4         For Mary Peltola, protecting this land or wate...
#                                 ...
# 942758    I happen to think the border is the biggest pr...
# 942759    Is this the America? You believe in the choice...
# 942760    A national abortion ban puts the lives of Long...
# 942761    A national abortion ban puts the lives of Long...
# 942762    Joe Morelli has never stopped fighting for our...
# Name: transcript, Length: 942763, dtype: str

# %%
df['transcript'][0]
# Out:
# "Wanna sit in the exam room and make decisions for you. Not only is that wrong, it's dangerous. Mark Robertson supports a near total ban on abortion. No exceptions. He even wants to criminalize abortion, sending women and doctors to prison. His position is so extreme. It could lead to a ban of birth control and IVF and I'll fight like hell to make sure that never happens. I'm Dena Titus and I approve this message because I'll always protect a woman's right to make her own choices. Hey, Hugh."

# %%
import pandas as pd
df = pd.read_stata("Ads2024_House_090124-110624_ASR_wmpid_coding_013026.dta")

df.head()
# Out:
#                                        alt  \
# 0       HOUSE_AK01_AAN_THIS_WAS_OUR_BORDER
# 1   HOUSE_AK01_BEGICH_CHART_OUR_OWN_COURSE
# 2     HOUSE_AK01_BEGICH_NRCC_ATHENA_FULTON
# 3  HOUSE_AK01_BEGICH_NRCC_FEELING_THE_PAIN
# 4         HOUSE_AK01_BEGICH_NRCC_LEE_BAKER
#
#                                   creative  \
# 0       HOUSE/AK01 AAN THIS WAS OUR BORDER
# 1   HOUSE/AK01 BEGICH CHART OUR OWN COURSE
# 2     HOUSE/AK01 BEGICH&NRCC ATHENA FULTON
# 3  HOUSE/AK01 BEGICH&NRCC FEELING THE PAIN
# 4         HOUSE/AK01 BEGICH&NRCC LEE BAKER
#
#                                             asr_text      wmpid    cand_id  \
# 0  This was our border, then it moved 4,000 mi so...         NA         NA
# 1  In Alaska, we've always chartered our own cour...  WMPID4003  H2AK01083
# 2  My son, Braden, was 20 years old when he passe...         NA         NA
# 3  We're all feeling the pain. Everything is more...         NA         NA
# ...

# %%
list(df.keys())
# Out:
# ['alt',
#  'creative',
#  'asr_text',
#  'wmpid',
#  'cand_id',
#  'weslink',
#  'market2010',
#  'nielsendmaid',
#  'sponsor',
#  'category',
#  'categorystate',
#  'l',
#  'market',
#  'district',
#  'media',
#  'airdate',
#  'airtime',
#  'daypart',
#  'station',
#  'affiliate',
#  'program',
#  'programtype',
#  'estcost',
#  'adtype',
#  'affiliation',
#  'election',
#  'issue',
#  'level',
#  'race',
#  'tone',
#  'year',
#  'N_BREAK',
#  'issue_aarpfraud',
#  'issue_aarp',
#  'issue_anticlinton',
#  'issue_antikaine',
#  'issue_antiobamamessage',
#  'issue_antipence',
#  'issue_antisanders',
#  'issue_antitrump',
#  'issue_anticruz',
#  'issue_budget',
#  'issue_calltoaction',
#  'issue_campaignfinance',
#  'issue_caregiving',
#  'issue_charities',
#  'issue_corruption',
#  'issue_defense',
#  'issue_domabuse',
#  'issue_economy',
#  'issue_ed',
#  'issue_energyenv',
#  'issue_enenv_antiepa',
#  'issue_enenv_coal',
#  'issue_enenv_coalanti',
#  'issue_enenv_coalpro',
# ...

# %%
df["transcript"][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/delta_lab/data/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transcript'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ...

# %%
df_no_coding = pd.read_stata("Ads2024_IssuesbyCreative_090124-110624_HSE_AI_013026.dta")

# %%
df_no_coding.head()
# Out:
#   advertiser_party advertiser_type            advertiser    airdate  \
# 0         Democrat       Candidate    Titus for NV CD-01 2024-09-13
# 1         Democrat       Candidate    Hoyle for OR CD-04 2024-09-03
# 2         Democrat       Candidate  Vasquez for NM CD-02 2024-09-11
# 3       Republican     Issue Group                  NRCC 2024-09-13
# 4      Independent     Issue Group             Fairshake 2024-09-05
#
#   election_state               election         issue_1        issue_2  \
# 0             NV  NV CD-01 2024 General        Abortion          Crime
# 1             OR  OR CD-04 2024 General       Education           Jobs
# 2             NM  NM CD-02 2024 General  Bipartisanship    Immigration
# 3             AK  AK CD-AL 2024 General       Joe Biden  Kamala Harris
# 4             AK  AK CD-AL 2024 General        Abortion    Environment
#
#      issue_3                    market  ...  issue_spanlang  primary  special  \
# ...

# %%
list(df_no_coding.keys())
# Out:
# ['advertiser_party',
#  'advertiser_type',
#  'advertiser',
#  'airdate',
#  'election_state',
#  'election',
#  'issue_1',
#  'issue_2',
#  'issue_3',
#  'market',
#  'spent',
#  'grps',
#  'viewers',
#  'grps_55',
#  'viewers_55',
#  'spot_length',
#  'station_state',
#  'station',
#  'target',
#  'title',
#  'tone',
#  'tagdate',
#  'time_ran',
#  'national',
#  'universe',
#  'fp_uuid',
#  'uuid',
#  'row_num',
#  'grps_18_49',
#  'viewers_18_49',
#  'grps_25_54',
#  'viewers_25_54',
#  'language',
#  'race',
#  'creative_type',
#  'impressions',
#  'media_type',
#  'digital_source_id',
#  'timezone',
#  'daypart',
#  'program_name',
#  'media_date',
#  'genre',
#  'callback_start_time',
#  'callback_end_time',
#  'overlap',
#  'universe_18_49',
#  'universe_25_54',
#  'universe_55_plus',
#  'buy_id',
#  'affiliate',
#  'advertiser_id',
#  'secondary_election',
#  'tertiary_election',
#  'secondary_target',
#  'tertiary_target',
#  'issue_spanlang',
#  'primary',
#  'special',
# ...

# %%
df_no_coding['transcript'][0]
# Out:
# "Wanna sit in the exam room and make decisions for you. Not only is that wrong, it's dangerous. Mark Robertson supports a near total ban on abortion. No exceptions. He even wants to criminalize abortion, sending women and doctors to prison. His position is so extreme. It could lead to a ban of birth control and IVF and I'll fight like hell to make sure that never happens. I'm Dena Titus and I approve this message because I'll always protect a woman's right to make her own choices. Hey, Hugh."

# %%
import pandas as pd

# %%
df_csv = pd.read_csv('../data/Ads2024_IssuesbyCreative_090124-110624_HSE_AI_013026.csv')

# %%
df_csv.head()
# Out:
#   advertiser_party advertiser_type            advertiser     airdate  \
# 0         Democrat       Candidate    Titus for NV CD-01  2024-09-13
# 1         Democrat       Candidate    Hoyle for OR CD-04  2024-09-03
# 2         Democrat       Candidate  Vasquez for NM CD-02  2024-09-11
# 3       Republican     Issue Group                  NRCC  2024-09-13
# 4      Independent     Issue Group             Fairshake  2024-09-05
#
#   election_state               election         issue_1        issue_2  \
# 0             NV  NV CD-01 2024 General        Abortion          Crime
# 1             OR  OR CD-04 2024 General       Education           Jobs
# 2             NM  NM CD-02 2024 General  Bipartisanship    Immigration
# 3             AK  AK CD-AL 2024 General       Joe Biden  Kamala Harris
# 4             AK  AK CD-AL 2024 General        Abortion    Environment
#
#      issue_3                    market  ...  issue_spanlang  primary  special  \
# ...

# %%
list(df_csv.keys())
# Out:
# ['advertiser_party',
#  'advertiser_type',
#  'advertiser',
#  'airdate',
#  'election_state',
#  'election',
#  'issue_1',
#  'issue_2',
#  'issue_3',
#  'market',
#  'spent',
#  'grps',
#  'viewers',
#  'grps_55',
#  'viewers_55',
#  'spot_length',
#  'station_state',
#  'station',
#  'target',
#  'title',
#  'tone',
#  'tagdate',
#  'time_ran',
#  'national',
#  'universe',
#  'fp_uuid',
#  'uuid',
#  'row_num',
#  'grps_18_49',
#  'viewers_18_49',
#  'grps_25_54',
#  'viewers_25_54',
#  'language',
#  'race',
#  'creative_type',
#  'impressions',
#  'media_type',
#  'digital_source_id',
#  'timezone',
#  'daypart',
#  'program_name',
#  'media_date',
#  'genre',
#  'callback_start_time',
#  'callback_end_time',
#  'overlap',
#  'universe_18_49',
#  'universe_25_54',
#  'universe_55_plus',
#  'buy_id',
#  'affiliate',
#  'advertiser_id',
#  'secondary_election',
#  'tertiary_election',
#  'secondary_target',
#  'tertiary_target',
#  'issue_spanlang',
#  'primary',
#  'special',
# ...

# %%
len(df_csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(df)
#
# NameError: name 'df' is not defined

# %%
df_csv['tone'][0:5]
# Out:
# 0    Contrast
# 1    Positive
# 2    Positive
# 3    Negative
# 4    Positive
# Name: tone, dtype: str
